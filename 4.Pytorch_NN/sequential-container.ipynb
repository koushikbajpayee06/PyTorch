# %%
import torch
import torch.nn as nn

class Model(nn.Module):

    def __init__(self,num_features):
        super().__init__()
        self.network = nn.Sequential(
            nn.Linear(num_features, 3),
            nn.ReLU(),
            nn.Linear(3,1),
            nn.Sigmoid()
        )

    def forward(self, features):
        out = self.network(features)
        return out

# %%
# create dataset
features = torch.rand(10,5)
# create a model
model = Model(features.shape[1])
#call model for forward pass
model(features)
# Out:
# tensor([[0.4625],
#         [0.4607],
#         [0.4607],
#         [0.4607],
#         [0.4607],
#         [0.4607],
#         [0.4594],
#         [0.4607],
#         [0.4556],
#         [0.4607]], grad_fn=<SigmoidBackward0>)

# %%
# show model weights
model.linear.weight
# Out:
# ---------------------------------------------------------------------------
# AttributeError                            Traceback (most recent call last)
# Cell In[8], line 2
#       1 # show model weights
# ----> 2 model.linear.weight
#
# File d:\PyTorch\.venv\Lib\site-packages\torch\nn\modules\module.py:1968, in Module.__getattr__(self, name)
#    1966     if name in modules:
#    1967         return modules[name]
# -> 1968 raise AttributeError(
#    1969     f"'{type(self).__name__}' object has no attribute '{name}'"
#    1970 )
#
# AttributeError: 'Model' object has no attribute 'linear'
